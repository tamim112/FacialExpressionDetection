# %%
"""
Description: Train emotion classification model
"""

from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2
import pandas as pd
import cv2
import numpy as np

dataset_path = 'fer2013/fer2013.csv'
image_size=(48,48)
# parameters
batch_size = 32
num_epochs = 3
input_shape = (48, 48, 1)
validation_split = .2
verbose = 1
num_classes = 7
patience = 50
base_path = 'models/'
l2_regularization=0.01


def load_fer2013():
	data = pd.read_csv(dataset_path)
	pixels = data['pixels'].tolist()
	width, height = 48, 48
	faces = []
	for pixel_sequence in pixels:
		face = [int(pixel) for pixel in pixel_sequence.split(' ')]
		face = np.asarray(face).reshape(width, height)
		face = cv2.resize(face.astype('uint8'),image_size)
		faces.append(face.astype('float32'))
	faces = np.asarray(faces)
	faces = np.expand_dims(faces, -1)
	emotions = pd.get_dummies(data['emotion']).as_matrix()
	return faces, emotions

def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x



# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)

# model parameters/compilation
# model = mini_XCEPTION(input_shape, num_classes)
regularization = l2(l2_regularization)

# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)

model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()

# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]

# loading dataset
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
num_samples, num_classes = emotions.shape
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)
model.fit_generator(data_generator.flow(xtrain, ytrain,
                                            batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# Using TensorFlow backend.
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 46, 46, 8)    72          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 46, 46, 8)    32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 46, 46, 8)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 44, 44, 8)    576         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 44, 44, 8)    32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 44, 44, 8)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 44, 44, 16)   200         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 44, 44, 16)   64          separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 44, 44, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 44, 44, 16)   400         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 44, 44, 16)   64          separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 22, 22, 16)   128         activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 22, 22, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 22, 22, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 22, 22, 16)   0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 22, 22, 32)   656         add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 22, 22, 32)   128         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 22, 22, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 22, 22, 32)   1312        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 22, 32)   128         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 11, 11, 32)   512         add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 11, 11, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 11, 11, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 11, 11, 32)   0           max_pooling2d_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 11, 11, 64)   2336        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 11, 11, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 11, 11, 64)   4672        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 6, 6, 64)     2048        add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 6, 6, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 64)     0           max_pooling2d_3[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 6, 6, 128)    8768        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 6, 6, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 6, 6, 128)    17536       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 3, 3, 128)    8192        add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 3, 3, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, 3, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 3, 3, 128)    0           max_pooling2d_4[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 3, 3, 7)      8071        add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 7)            0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\ipykernel_launcher.py:50: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# WARNING:tensorflow:From C:\Users\TAMIM\AppData\Local\conda\conda\envs\face\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 898/897 [==============================] - 658s 732ms/step - loss: 1.7646 - accuracy: 0.3333 - val_loss: 1.6980 - val_accuracy: 0.3962
#
# Epoch 00001: val_loss improved from inf to 1.69797, saving model to models/_mini_XCEPTION.01-0.40.hdf5
# Epoch 2/100
# 898/897 [==============================] - 559s 623ms/step - loss: 1.5007 - accuracy: 0.4398 - val_loss: 1.5765 - val_accuracy: 0.4256
#
# Epoch 00002: val_loss improved from 1.69797 to 1.57650, saving model to models/_mini_XCEPTION.02-0.43.hdf5
# Epoch 3/100
# 898/897 [==============================] - 545s 607ms/step - loss: 1.3949 - accuracy: 0.4796 - val_loss: 1.3421 - val_accuracy: 0.4936
#
# Epoch 00003: val_loss improved from 1.57650 to 1.34211, saving model to models/_mini_XCEPTION.03-0.49.hdf5
# Epoch 4/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.3297 - accuracy: 0.5002 - val_loss: 1.3156 - val_accuracy: 0.4999
#
# Epoch 00004: val_loss improved from 1.34211 to 1.31562, saving model to models/_mini_XCEPTION.04-0.50.hdf5
# Epoch 5/100
# 898/897 [==============================] - 543s 604ms/step - loss: 1.2786 - accuracy: 0.5221 - val_loss: 1.2900 - val_accuracy: 0.5205
#
# Epoch 00005: val_loss improved from 1.31562 to 1.28996, saving model to models/_mini_XCEPTION.05-0.52.hdf5
# Epoch 6/100
# 898/897 [==============================] - 544s 606ms/step - loss: 1.2464 - accuracy: 0.5303 - val_loss: 1.2415 - val_accuracy: 0.5327
#
# Epoch 00006: val_loss improved from 1.28996 to 1.24151, saving model to models/_mini_XCEPTION.06-0.53.hdf5
# Epoch 7/100
# 898/897 [==============================] - 544s 606ms/step - loss: 1.2133 - accuracy: 0.5474 - val_loss: 1.2102 - val_accuracy: 0.5510
#
# Epoch 00007: val_loss improved from 1.24151 to 1.21015, saving model to models/_mini_XCEPTION.07-0.55.hdf5
# Epoch 8/100
# 898/897 [==============================] - 544s 605ms/step - loss: 1.2020 - accuracy: 0.5524 - val_loss: 1.2574 - val_accuracy: 0.5286
#
# Epoch 00008: val_loss did not improve from 1.21015
# Epoch 9/100
# 898/897 [==============================] - 647s 721ms/step - loss: 1.1794 - accuracy: 0.5564 - val_loss: 1.1699 - val_accuracy: 0.5660
#
# Epoch 00009: val_loss improved from 1.21015 to 1.16986, saving model to models/_mini_XCEPTION.09-0.57.hdf5
# Epoch 10/100
# 898/897 [==============================] - 660s 734ms/step - loss: 1.1632 - accuracy: 0.5631 - val_loss: 1.2232 - val_accuracy: 0.5446
#
# Epoch 00010: val_loss did not improve from 1.16986
# Epoch 11/100
# 898/897 [==============================] - 617s 687ms/step - loss: 1.1459 - accuracy: 0.5694 - val_loss: 1.2127 - val_accuracy: 0.5490
#
# Epoch 00011: val_loss did not improve from 1.16986
# Epoch 12/100
# 898/897 [==============================] - 601s 669ms/step - loss: 1.1317 - accuracy: 0.5746 - val_loss: 1.1554 - val_accuracy: 0.5694
#
# Epoch 00012: val_loss improved from 1.16986 to 1.15539, saving model to models/_mini_XCEPTION.12-0.57.hdf5
# Epoch 13/100
# 898/897 [==============================] - 664s 739ms/step - loss: 1.1232 - accuracy: 0.5810 - val_loss: 1.1361 - val_accuracy: 0.5773
#
# Epoch 00013: val_loss improved from 1.15539 to 1.13609, saving model to models/_mini_XCEPTION.13-0.58.hdf5
# Epoch 14/100
# 898/897 [==============================] - 686s 764ms/step - loss: 1.1148 - accuracy: 0.5814 - val_loss: 1.1326 - val_accuracy: 0.5776
#
# Epoch 00014: val_loss improved from 1.13609 to 1.13259, saving model to models/_mini_XCEPTION.14-0.58.hdf5
# Epoch 15/100
# 898/897 [==============================] - 693s 771ms/step - loss: 1.1043 - accuracy: 0.5865 - val_loss: 1.1538 - val_accuracy: 0.5805
#
# Epoch 00015: val_loss did not improve from 1.13259
# Epoch 16/100
# 898/897 [==============================] - 626s 697ms/step - loss: 1.0955 - accuracy: 0.5897 - val_loss: 1.1072 - val_accuracy: 0.5879
#
# Epoch 00016: val_loss improved from 1.13259 to 1.10715, saving model to models/_mini_XCEPTION.16-0.59.hdf5
# Epoch 17/100
# 898/897 [==============================] - 544s 606ms/step - loss: 1.0851 - accuracy: 0.5918 - val_loss: 1.1431 - val_accuracy: 0.5818
#
# Epoch 00017: val_loss did not improve from 1.10715
# Epoch 18/100
# 898/897 [==============================] - 544s 606ms/step - loss: 1.0825 - accuracy: 0.5952 - val_loss: 1.1636 - val_accuracy: 0.5777
#
# Epoch 00018: val_loss did not improve from 1.10715
# Epoch 19/100
# 898/897 [==============================] - 542s 604ms/step - loss: 1.0750 - accuracy: 0.5961 - val_loss: 1.0872 - val_accuracy: 0.5988
#
# Epoch 00019: val_loss improved from 1.10715 to 1.08719, saving model to models/_mini_XCEPTION.19-0.60.hdf5
# Epoch 20/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.0667 - accuracy: 0.6028 - val_loss: 1.0711 - val_accuracy: 0.6002
#
# Epoch 00020: val_loss improved from 1.08719 to 1.07110, saving model to models/_mini_XCEPTION.20-0.60.hdf5
# Epoch 21/100
# 898/897 [==============================] - 543s 604ms/step - loss: 1.0540 - accuracy: 0.6052 - val_loss: 1.0924 - val_accuracy: 0.6011
#
# Epoch 00021: val_loss did not improve from 1.07110
# Epoch 22/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.0478 - accuracy: 0.6083 - val_loss: 1.0872 - val_accuracy: 0.6131
#
# Epoch 00022: val_loss did not improve from 1.07110
# Epoch 23/100
# 898/897 [==============================] - 543s 604ms/step - loss: 1.0500 - accuracy: 0.6042 - val_loss: 1.0802 - val_accuracy: 0.5967
#
# Epoch 00023: val_loss did not improve from 1.07110
# Epoch 24/100
# 898/897 [==============================] - 544s 605ms/step - loss: 1.0393 - accuracy: 0.6132 - val_loss: 1.0720 - val_accuracy: 0.6089
#
# Epoch 00024: val_loss did not improve from 1.07110
# Epoch 25/100
# 898/897 [==============================] - 544s 605ms/step - loss: 1.0347 - accuracy: 0.6141 - val_loss: 1.0983 - val_accuracy: 0.5949
#
# Epoch 00025: val_loss did not improve from 1.07110
# Epoch 26/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.0349 - accuracy: 0.6150 - val_loss: 1.0700 - val_accuracy: 0.6078
#
# Epoch 00026: val_loss improved from 1.07110 to 1.07004, saving model to models/_mini_XCEPTION.26-0.61.hdf5
# Epoch 27/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.0199 - accuracy: 0.6201 - val_loss: 1.0841 - val_accuracy: 0.5947
#
# Epoch 00027: val_loss did not improve from 1.07004
# Epoch 28/100
# 898/897 [==============================] - 551s 614ms/step - loss: 1.0201 - accuracy: 0.6187 - val_loss: 1.0981 - val_accuracy: 0.5874
#
# Epoch 00028: val_loss did not improve from 1.07004
# Epoch 29/100
# 898/897 [==============================] - 542s 604ms/step - loss: 1.0147 - accuracy: 0.6205 - val_loss: 1.2023 - val_accuracy: 0.5599
#
# Epoch 00029: val_loss did not improve from 1.07004
# Epoch 30/100
# 898/897 [==============================] - 543s 604ms/step - loss: 1.0089 - accuracy: 0.6249 - val_loss: 1.0364 - val_accuracy: 0.6186
#
# Epoch 00030: val_loss improved from 1.07004 to 1.03637, saving model to models/_mini_XCEPTION.30-0.62.hdf5
# Epoch 31/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.0072 - accuracy: 0.6278 - val_loss: 1.1038 - val_accuracy: 0.5936
#
# Epoch 00031: val_loss did not improve from 1.03637
# Epoch 32/100
# 898/897 [==============================] - 543s 605ms/step - loss: 1.0080 - accuracy: 0.6220 - val_loss: 1.0316 - val_accuracy: 0.6227
#
# Epoch 00032: val_loss improved from 1.03637 to 1.03158, saving model to models/_mini_XCEPTION.32-0.62.hdf5
# Epoch 33/100
# 898/897 [==============================] - 543s 604ms/step - loss: 1.0016 - accuracy: 0.6298 - val_loss: 1.0645 - val_accuracy: 0.6179
#
# Epoch 00033: val_loss did not improve from 1.03158
# Epoch 34/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.9986 - accuracy: 0.6256 - val_loss: 1.0504 - val_accuracy: 0.6158
#
# Epoch 00034: val_loss did not improve from 1.03158
# Epoch 35/100
# 898/897 [==============================] - 543s 604ms/step - loss: 0.9939 - accuracy: 0.6269 - val_loss: 1.0826 - val_accuracy: 0.6006
#
# Epoch 00035: val_loss did not improve from 1.03158
# Epoch 36/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.9925 - accuracy: 0.6301 - val_loss: 1.0884 - val_accuracy: 0.6045
#
# Epoch 00036: val_loss did not improve from 1.03158
# Epoch 37/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.9907 - accuracy: 0.6296 - val_loss: 1.1007 - val_accuracy: 0.5933
#
# Epoch 00037: val_loss did not improve from 1.03158
# Epoch 38/100
# 898/897 [==============================] - 542s 603ms/step - loss: 0.9817 - accuracy: 0.6347 - val_loss: 1.0597 - val_accuracy: 0.6137
#
# Epoch 00038: val_loss did not improve from 1.03158
# Epoch 39/100
# 898/897 [==============================] - 541s 603ms/step - loss: 0.9769 - accuracy: 0.6370 - val_loss: 1.0438 - val_accuracy: 0.6126
#
# Epoch 00039: val_loss did not improve from 1.03158
# Epoch 40/100
# 898/897 [==============================] - 549s 611ms/step - loss: 0.9781 - accuracy: 0.6356 - val_loss: 1.0686 - val_accuracy: 0.6159
#
# Epoch 00040: val_loss did not improve from 1.03158
# Epoch 41/100
# 898/897 [==============================] - 548s 610ms/step - loss: 0.9701 - accuracy: 0.6364 - val_loss: 1.0198 - val_accuracy: 0.6222
#
# Epoch 00041: val_loss improved from 1.03158 to 1.01979, saving model to models/_mini_XCEPTION.41-0.62.hdf5
# Epoch 42/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.9704 - accuracy: 0.6361 - val_loss: 1.0789 - val_accuracy: 0.6064
#
# Epoch 00042: val_loss did not improve from 1.01979
# Epoch 43/100
# 898/897 [==============================] - 542s 603ms/step - loss: 0.9699 - accuracy: 0.6357 - val_loss: 1.0700 - val_accuracy: 0.6080
#
# Epoch 00043: val_loss did not improve from 1.01979
# Epoch 44/100
# 898/897 [==============================] - 541s 603ms/step - loss: 0.9623 - accuracy: 0.6396 - val_loss: 1.0481 - val_accuracy: 0.6179
#
# Epoch 00044: val_loss did not improve from 1.01979
# Epoch 45/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.9597 - accuracy: 0.6432 - val_loss: 1.0769 - val_accuracy: 0.6138
#
# Epoch 00045: val_loss did not improve from 1.01979
# Epoch 46/100
# 898/897 [==============================] - 542s 603ms/step - loss: 0.9664 - accuracy: 0.6391 - val_loss: 1.0625 - val_accuracy: 0.6163
#
# Epoch 00046: val_loss did not improve from 1.01979
# Epoch 47/100
# 898/897 [==============================] - 543s 604ms/step - loss: 0.9613 - accuracy: 0.6421 - val_loss: 1.0489 - val_accuracy: 0.6124
#
# Epoch 00047: val_loss did not improve from 1.01979
# Epoch 48/100
# 898/897 [==============================] - 541s 603ms/step - loss: 0.9608 - accuracy: 0.6435 - val_loss: 1.0529 - val_accuracy: 0.6160
#
# Epoch 00048: val_loss did not improve from 1.01979
# Epoch 49/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.9480 - accuracy: 0.6460 - val_loss: 1.0295 - val_accuracy: 0.6213
#
# Epoch 00049: val_loss did not improve from 1.01979
# Epoch 50/100
# 898/897 [==============================] - 541s 603ms/step - loss: 0.9530 - accuracy: 0.6474 - val_loss: 1.0589 - val_accuracy: 0.6105
#
# Epoch 00050: val_loss did not improve from 1.01979
# Epoch 51/100
# 898/897 [==============================] - 545s 607ms/step - loss: 0.9487 - accuracy: 0.6473 - val_loss: 1.0695 - val_accuracy: 0.6084
#
# Epoch 00051: val_loss did not improve from 1.01979
# Epoch 52/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.9422 - accuracy: 0.6500 - val_loss: 1.0613 - val_accuracy: 0.6062
#
# Epoch 00052: val_loss did not improve from 1.01979
# Epoch 53/100
# 898/897 [==============================] - 544s 606ms/step - loss: 0.9426 - accuracy: 0.6459 - val_loss: 1.0826 - val_accuracy: 0.6060
#
# Epoch 00053: val_loss did not improve from 1.01979
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 54/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.9005 - accuracy: 0.6674 - val_loss: 0.9789 - val_accuracy: 0.6385
#
# Epoch 00054: val_loss improved from 1.01979 to 0.97891, saving model to models/_mini_XCEPTION.54-0.64.hdf5
# Epoch 55/100
# 898/897 [==============================] - 543s 604ms/step - loss: 0.8793 - accuracy: 0.6745 - val_loss: 0.9832 - val_accuracy: 0.6379
#
# Epoch 00055: val_loss did not improve from 0.97891
# Epoch 56/100
# 898/897 [==============================] - 4572s 5s/step - loss: 0.8766 - accuracy: 0.6756 - val_loss: 0.9853 - val_accuracy: 0.6361
#
# Epoch 00056: val_loss did not improve from 0.97891
# Epoch 57/100
# 898/897 [==============================] - 548s 610ms/step - loss: 0.8737 - accuracy: 0.6789 - val_loss: 0.9815 - val_accuracy: 0.6374
#
# Epoch 00057: val_loss did not improve from 0.97891
# Epoch 58/100
# 898/897 [==============================] - 544s 605ms/step - loss: 0.8705 - accuracy: 0.6766 - val_loss: 0.9763 - val_accuracy: 0.6408
#
# Epoch 00058: val_loss improved from 0.97891 to 0.97627, saving model to models/_mini_XCEPTION.58-0.64.hdf5
# Epoch 59/100
# 898/897 [==============================] - 544s 606ms/step - loss: 0.8656 - accuracy: 0.6799 - val_loss: 0.9833 - val_accuracy: 0.6397
#
# Epoch 00059: val_loss did not improve from 0.97627
# Epoch 60/100
# 898/897 [==============================] - 547s 609ms/step - loss: 0.8631 - accuracy: 0.6814 - val_loss: 0.9780 - val_accuracy: 0.6397
#
# Epoch 00060: val_loss did not improve from 0.97627
# Epoch 61/100
# 898/897 [==============================] - 544s 606ms/step - loss: 0.8584 - accuracy: 0.6807 - val_loss: 0.9779 - val_accuracy: 0.6418
#
# Epoch 00061: val_loss did not improve from 0.97627
# Epoch 62/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.8545 - accuracy: 0.6812 - val_loss: 0.9845 - val_accuracy: 0.6364
#
# Epoch 00062: val_loss did not improve from 0.97627
# Epoch 63/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.8577 - accuracy: 0.6807 - val_loss: 0.9831 - val_accuracy: 0.6402
#
# Epoch 00063: val_loss did not improve from 0.97627
# Epoch 64/100
# 898/897 [==============================] - 548s 610ms/step - loss: 0.8543 - accuracy: 0.6849 - val_loss: 0.9897 - val_accuracy: 0.6339
#
# Epoch 00064: val_loss did not improve from 0.97627
# Epoch 65/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.8533 - accuracy: 0.6816 - val_loss: 0.9798 - val_accuracy: 0.6389
#
# Epoch 00065: val_loss did not improve from 0.97627
# Epoch 66/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.8540 - accuracy: 0.6847 - val_loss: 0.9848 - val_accuracy: 0.6383
#
# Epoch 00066: val_loss did not improve from 0.97627
# Epoch 67/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.8571 - accuracy: 0.6792 - val_loss: 0.9807 - val_accuracy: 0.6369
#
# Epoch 00067: val_loss did not improve from 0.97627
# Epoch 68/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.8544 - accuracy: 0.6827 - val_loss: 0.9775 - val_accuracy: 0.6376
#
# Epoch 00068: val_loss did not improve from 0.97627
# Epoch 69/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.8507 - accuracy: 0.6849 - val_loss: 0.9811 - val_accuracy: 0.6390
#
# Epoch 00069: val_loss did not improve from 0.97627
# Epoch 70/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.8512 - accuracy: 0.6839 - val_loss: 0.9874 - val_accuracy: 0.6389
#
# Epoch 00070: val_loss did not improve from 0.97627
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 71/100
# 898/897 [==============================] - 544s 605ms/step - loss: 0.8385 - accuracy: 0.6900 - val_loss: 0.9819 - val_accuracy: 0.6390
#
# Epoch 00071: val_loss did not improve from 0.97627
# Epoch 72/100
# 898/897 [==============================] - 573s 638ms/step - loss: 0.8434 - accuracy: 0.6886 - val_loss: 0.9812 - val_accuracy: 0.6395
#
# Epoch 00072: val_loss did not improve from 0.97627
# Epoch 73/100
# 898/897 [==============================] - 543s 604ms/step - loss: 0.8420 - accuracy: 0.6868 - val_loss: 0.9825 - val_accuracy: 0.6390
#
# Epoch 00073: val_loss did not improve from 0.97627
# Epoch 74/100
# 898/897 [==============================] - 545s 607ms/step - loss: 0.8422 - accuracy: 0.6908 - val_loss: 0.9796 - val_accuracy: 0.6404
#
# Epoch 00074: val_loss did not improve from 0.97627
# Epoch 75/100
# 898/897 [==============================] - 617s 687ms/step - loss: 0.8392 - accuracy: 0.6903 - val_loss: 0.9785 - val_accuracy: 0.6404
#
# Epoch 00075: val_loss did not improve from 0.97627
# Epoch 76/100
# 898/897 [==============================] - 556s 619ms/step - loss: 0.8471 - accuracy: 0.6872 - val_loss: 0.9785 - val_accuracy: 0.6418
#
# Epoch 00076: val_loss did not improve from 0.97627
# Epoch 77/100
# 898/897 [==============================] - 543s 604ms/step - loss: 0.8422 - accuracy: 0.6861 - val_loss: 0.9779 - val_accuracy: 0.6392
#
# Epoch 00077: val_loss did not improve from 0.97627
# Epoch 78/100
# 898/897 [==============================] - 544s 606ms/step - loss: 0.8397 - accuracy: 0.6898 - val_loss: 0.9785 - val_accuracy: 0.6392
#
# Epoch 00078: val_loss did not improve from 0.97627
# Epoch 79/100
# 898/897 [==============================] - 543s 605ms/step - loss: 0.8448 - accuracy: 0.6855 - val_loss: 0.9798 - val_accuracy: 0.6392
#
# Epoch 00079: val_loss did not improve from 0.97627
# Epoch 80/100
# 898/897 [==============================] - 543s 604ms/step - loss: 0.8421 - accuracy: 0.6885 - val_loss: 0.9801 - val_accuracy: 0.6389
#
# Epoch 00080: val_loss did not improve from 0.97627
# Epoch 81/100
# 898/897 [==============================] - 545s 607ms/step - loss: 0.8379 - accuracy: 0.6898 - val_loss: 0.9787 - val_accuracy: 0.6392
#
# Epoch 00081: val_loss did not improve from 0.97627
# Epoch 82/100
# 898/897 [==============================] - 542s 604ms/step - loss: 0.8358 - accuracy: 0.6911 - val_loss: 0.9804 - val_accuracy: 0.6396
#
# Epoch 00082: val_loss did not improve from 0.97627
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 83/100
# 898/897 [==============================] - 4258s 5s/step - loss: 0.8387 - accuracy: 0.6900 - val_loss: 0.9810 - val_accuracy: 0.6393
#
# Epoch 00083: val_loss did not improve from 0.97627
# Epoch 84/100
# 898/897 [==============================] - 554s 617ms/step - loss: 0.8369 - accuracy: 0.6890 - val_loss: 0.9802 - val_accuracy: 0.6399
#
# Epoch 00084: val_loss did not improve from 0.97627
# Epoch 85/100
# 898/897 [==============================] - 557s 620ms/step - loss: 0.8398 - accuracy: 0.6855 - val_loss: 0.9805 - val_accuracy: 0.6386
#
# Epoch 00085: val_loss did not improve from 0.97627
# Epoch 86/100
# 898/897 [==============================] - 555s 618ms/step - loss: 0.8432 - accuracy: 0.6888 - val_loss: 0.9798 - val_accuracy: 0.6393
#
# Epoch 00086: val_loss did not improve from 0.97627
# Epoch 87/100
# 898/897 [==============================] - 570s 634ms/step - loss: 0.8373 - accuracy: 0.6898 - val_loss: 0.9805 - val_accuracy: 0.6393
#
# Epoch 00087: val_loss did not improve from 0.97627
# Epoch 88/100
# 898/897 [==============================] - 560s 624ms/step - loss: 0.8372 - accuracy: 0.6885 - val_loss: 0.9808 - val_accuracy: 0.6389
#
# Epoch 00088: val_loss did not improve from 0.97627
# Epoch 89/100
# 898/897 [==============================] - 558s 621ms/step - loss: 0.8416 - accuracy: 0.6895 - val_loss: 0.9790 - val_accuracy: 0.6403
#
# Epoch 00089: val_loss did not improve from 0.97627
# Epoch 90/100
# 898/897 [==============================] - 559s 622ms/step - loss: 0.8366 - accuracy: 0.6897 - val_loss: 0.9792 - val_accuracy: 0.6396
#
# Epoch 00090: val_loss did not improve from 0.97627
# Epoch 91/100
# 898/897 [==============================] - 596s 663ms/step - loss: 0.8382 - accuracy: 0.6906 - val_loss: 0.9799 - val_accuracy: 0.6396
#
# Epoch 00091: val_loss did not improve from 0.97627
# Epoch 92/100
# 898/897 [==============================] - 571s 636ms/step - loss: 0.8382 - accuracy: 0.6883 - val_loss: 0.9792 - val_accuracy: 0.6397
#
# Epoch 00092: val_loss did not improve from 0.97627
# Epoch 93/100
# 898/897 [==============================] - 560s 623ms/step - loss: 0.8382 - accuracy: 0.6876 - val_loss: 0.9811 - val_accuracy: 0.6392
#
# Epoch 00093: val_loss did not improve from 0.97627
# Epoch 94/100
# 898/897 [==============================] - 557s 620ms/step - loss: 0.8391 - accuracy: 0.6876 - val_loss: 0.9798 - val_accuracy: 0.6393
#
# Epoch 00094: val_loss did not improve from 0.97627
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 95/100
# 898/897 [==============================] - 545s 607ms/step - loss: 0.8406 - accuracy: 0.6879 - val_loss: 0.9791 - val_accuracy: 0.6393
#
# Epoch 00095: val_loss did not improve from 0.97627
# Epoch 96/100
# 898/897 [==============================] - 7394s 8s/step - loss: 0.8377 - accuracy: 0.6886 - val_loss: 0.9797 - val_accuracy: 0.6395
#
# Epoch 00096: val_loss did not improve from 0.97627
# Epoch 97/100
# 898/897 [==============================] - 552s 614ms/step - loss: 0.8374 - accuracy: 0.6883 - val_loss: 0.9787 - val_accuracy: 0.6403
#
# Epoch 00097: val_loss did not improve from 0.97627
# Epoch 98/100
# 898/897 [==============================] - 556s 619ms/step - loss: 0.8396 - accuracy: 0.6880 - val_loss: 0.9801 - val_accuracy: 0.6395
#
# Epoch 00098: val_loss did not improve from 0.97627
# Epoch 99/100
# 898/897 [==============================] - 638s 710ms/step - loss: 0.8414 - accuracy: 0.6892 - val_loss: 0.9798 - val_accuracy: 0.6390
#
# Epoch 00099: val_loss did not improve from 0.97627
# Epoch 100/100
# 898/897 [==============================] - 931s 1s/step - loss: 0.8434 - accuracy: 0.6871 - val_loss: 0.9795 - val_accuracy: 0.6385
#
# Epoch 00100: val_loss did not improve from 0.97627

# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import imutils
import cv2
import numpy as np
import sys

# parameters for loading data and images
detection_model_path = 'haarcascade_files/haarcascade_frontalface_default.xml'
emotion_model_path = 'models/_mini_XCEPTION.106-0.65.hdf5'
img_path = 'test/happy9.jpeg'

# hyper-parameters for bounding boxes shape
# loading models
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ["angry","disgust","scared", "happy", "sad", "surprised","neutral"]


#reading the frame
orig_frame = cv2.imread(img_path) 
frame = cv2.imread(img_path,0)
faces = face_detection.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=5,minSize=(30,30),flags=cv2.CASCADE_SCALE_IMAGE)

if len(faces) > 0:
    faces = sorted(faces, reverse=True,key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))[0]
    (fX, fY, fW, fH) = faces
    roi = frame[fY:fY + fH, fX:fX + fW]
    roi = cv2.resize(roi, (48, 48))
    roi = roi.astype("float") / 255.0
    roi = img_to_array(roi)
    roi = np.expand_dims(roi, axis=0)
    preds = emotion_classifier.predict(roi)[0]
    emotion_probability = np.max(preds)
    label = EMOTIONS[preds.argmax()]
    cv2.putText(orig_frame, label, (fX, fY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
    cv2.rectangle(orig_frame, (fX, fY), (fX + fW, fY + fH),(0, 0, 255), 2)
    
cv2.imshow('test_face', orig_frame)
cv2.imwrite('test_output/'+img_path.split('/')[-1],orig_frame)
if (cv2.waitKey(10000) & 0xFF == ord('q')):
    sys.exit("Thanks")
cv2.destroyAllWindows()

# %%
from keras.preprocessing.image import img_to_array
import imutils
import cv2
from keras.models import load_model
import numpy as np

# parameters for loading data and images
detection_model_path = 'haarcascade_files/haarcascade_frontalface_default.xml'
emotion_model_path = 'models/_mini_XCEPTION.106-0.65.hdf5'

# hyper-parameters for bounding boxes shape
# loading models
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ["angry" ,"disgust","scared", "happy", "sad", "surprised",
 "neutral"]


# starting video streaming
cv2.namedWindow('your_face')
camera = cv2.VideoCapture(0)
while True:
    frame = camera.read()[1]
    #reading the frame
    frame = imutils.resize(frame,width=400)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_detection.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5,minSize=(30,30),flags=cv2.CASCADE_SCALE_IMAGE)
    
    canvas = np.zeros((250, 300, 3), dtype="uint8")
    frameClone = frame.copy()
    if len(faces) > 0:
        faces = sorted(faces, reverse=True,
        key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))[0]
        (fX, fY, fW, fH) = faces
                    # Extract the ROI of the face from the grayscale image, resize it to a fixed 48x48 pixels, and then prepare
            # the ROI for classification via the CNN
        roi = gray[fY:fY + fH, fX:fX + fW]
        roi = cv2.resize(roi, (48, 48))
        roi = roi.astype("float") / 255.0
        roi = img_to_array(roi)
        roi = np.expand_dims(roi, axis=0)
        
        
        preds = emotion_classifier.predict(roi)[0]
        emotion_probability = np.max(preds)
        label = EMOTIONS[preds.argmax()]

 
    for (i, (emotion, prob)) in enumerate(zip(EMOTIONS, preds)):
                # construct the label textq
                text = "{}: {:.2f}%".format(emotion, prob * 100)
                w = int(prob * 300)
                cv2.rectangle(canvas, (7, (i * 35) + 5),
                (w, (i * 35) + 35), (0, 0, 255), -1)
                cv2.putText(canvas, text, (10, (i * 35) + 23),
                cv2.FONT_HERSHEY_SIMPLEX, 0.45,
                (255, 255, 255), 2)
                cv2.putText(frameClone, label, (fX, fY - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
                cv2.rectangle(frameClone, (fX, fY), (fX + fW, fY + fH),
                              (0, 0, 255), 2)

    cv2.imshow('your_face', frameClone)
    cv2.imshow("Probabilities", canvas)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

camera.release()
cv2.destroyAllWindows()
